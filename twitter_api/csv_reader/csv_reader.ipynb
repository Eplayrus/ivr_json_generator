# %%
import pandas as pd

# указать правильную кодировку для файла
df = pd.read_csv('DataExport_2024-12-27_16-13-15.csv', sep='\t', encoding='cp1251')

# Теперь создаем словарь
data_dict = df.to_dict(orient='records')

for item in  data_dict:
    print(item.keys())


print(data_dict)
# Out:
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# dict_keys(['theme,value'])
# [{'theme,value': 'PickerApp DC,"1,31"'}, {'theme,value': 'Авторизация,"1,37"'}, {'theme,value': 'Админка CTT,"1,45"'}, {'theme,value': 'Админка Такси,"2,79"'}, {'theme,value': 'Адрес ресторана,"1,48"'}, {'theme,value': 'Акции,"1,8"'}, {'theme,value': 'Баннеры и подборки,"1,6"'}, {'theme,value': 'Биометрия,"1,24"'}, {'theme,value': 'Блокировка аккаунта,"0,91"'}, {'theme,value': 'Блюдо выходит из стоп-листа раньше времени,"2,31"'}, {'theme,value': 'Блюдо из стоп-листа в заказе,"2,54"'}, {'theme,value': 'Блюдо не снимается со стоп-листа,"2,21"'}, {'theme,value': 'Блюдо не ставится в стоп-лист,"2,28"'}, {'theme,value': 'Бухгалтерия и отчёты,"2,49"'}, {'theme,value': 'Визуальная ошибка - не блокирует работу,"0,78"'}, {'theme,value': 'Визуальная проблема интерфейса,"2,38"'}, {'theme,value': 'Вопрос исключительно по Умной цене,"4,68"'}, {'theme,value': 'Вопрос по платной подписке,"2,17"'}, {'theme,value': 'Вопросы по разделу,"1,67"'}, {'theme,value': 'Время доставки,"2,63"'}, {'theme,value': 'Вылетает приложение,"1,72"'}, {'theme,value': 'Дали мало / много времени на готовку,3'}, {'theme,value': 'Данные в профиле,"2,28"'}, {'theme,value': 'Данные о клиенте в заказе,"2,58"'}, {'theme,value': 'Доставка и самовывоз,"3,61"'}, {'theme,value': 'Достижения,"2,36"'}, {'theme,value': 'Доступен только для предзаказа,"2,88"'}, {'theme,value': 'Другая ошибка,"3,04"'}, {'theme,value': 'Другое,"3,45"'}, {'theme,value': 'Другое время на сайте,"3,03"'}, {'theme,value': 'Еда в городе,"2,2"'}, {'theme,value': 'Жучок,"0,29"'}, {'theme,value': 'Завершение слота,"2,86"'}, {'theme,value': 'Заказ,"0,86"'}, {'theme,value': 'Заказ не по графику работы зоны ресторана,"3,26"'}, {'theme,value': 'Изменение заказа рестораном,"3,19"'}, {'theme,value': 'Информация о Лиде,"2,68"'}, {'theme,value': 'Информация об отмене не поступила в ресторан,"1,77"'}, {'theme,value': 'История заказов,"1,3"'}, {'theme,value': 'Картинки,"2,87"'}, {'theme,value': 'Карточка заказа,"2,06"'}, {'theme,value': 'Каталог,"1,35"'}, {'theme,value': 'Корзина,"2,84"'}, {'theme,value': 'Корпоративный способ оплаты,"2,54"'}, {'theme,value': 'Маркетплейс аренды,"2,84"'}, {'theme,value': 'Мед книжка,"0,94"'}, {'theme,value': 'Меню,"2,31"'}, {'theme,value': 'Мешает оформить заказ,"1,56"'}, {'theme,value': 'Мультизаказ,"2,26"'}, {'theme,value': 'Начало слота,"2,97"'}, {'theme,value': 'Не вернулись деньги,"0,73"'}, {'theme,value': 'Не видит тестовый заказ,"1,02"'}, {'theme,value': 'Не видно заказа,"1,81"'}, {'theme,value': 'Не видно на сайте,"2,64"'}, {'theme,value': 'Не выгружается id терминала в группе,"0,95"'}, {'theme,value': 'Не добавляется картинка к блюду,"3,19"'}, {'theme,value': 'Не доплатили,"1,49"'}, {'theme,value': 'Не заплатили,"1,56"'}, {'theme,value': 'Не запускается акция,3'}, {'theme,value': 'Не запускается продвижение,"3,15"'}, {'theme,value': 'Не меняется статус,"2,05"'}, {'theme,value': 'Не меняется статус заказа,"0,62"'}, {'theme,value': 'Не могу написать,"1,55"'}, {'theme,value': 'Не могу связаться с курьером/рестораном,"3,36"'}, {'theme,value': 'Не может принять заказ,"1,76"'}, {'theme,value': 'Не может сбросить пароль,"0,69"'}, {'theme,value': 'Не парсится блюдо/категория,"3,1"'}, {'theme,value': 'Не парсится всё меню / возникает ошибка,"2,68"'}, {'theme,value': 'Не получается включить в админке,"0,99"'}, {'theme,value': 'Не получается добавить блюдо/категорию,"2,71"'}, {'theme,value': 'Не получается удалить/изменить блюдо,"2,43"'}, {'theme,value': 'Не понимает куда исчезли деньги,"2,91"'}, {'theme,value': 'Не поступает заказ,"1,61"'}, {'theme,value': 'Не поступает заказ в вендорку,"2,62"'}, {'theme,value': 'Не поступают заказы,"1,4"'}, {'theme,value': 'Не пришел еженедельный отчет,"2,01"'}, {'theme,value': 'Не пришел чек,"0,94"'}, {'theme,value': 'Не проходит оплата,"3,21"'}, {'theme,value': 'Не прошла оплата заказа,"0,29"'}, {'theme,value': 'Не работает действующая акция,"3,05"'}, {'theme,value': 'Не редактируется время,"3,3"'}, {'theme,value': 'Не редактируется зона,"2,31"'}, ...

# %%
for item in  data_dict:
    print(item.get("theme"))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
